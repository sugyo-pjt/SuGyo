# %% [markdown]
# # 수어 인식 모델 - CNN + LSTM + Attention
#
# 이 노트북은 수어 인식을 위한 CNN + LSTM 하이브리드 모델을 구현합니다.
#
# ## 주요 특징
# - 버킷 기반 시퀀스 길이 정규화
# - 에러 처리 및 검증
# - GPU 최적화
# - 실시간 예측 지원

# %% [markdown]
# ## 1. 라이브러리 및 설정

# %%
# %pip install -r requirements.txt
# Out:
# Requirement already satisfied: tensorflow==2.14.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from -r requirements.txt (line 2)) (2.14.0)
# Requirement already satisfied: keras==2.14.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from -r requirements.txt (line 3)) (2.14.0)
# Requirement already satisfied: tensorboard==2.14.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from -r requirements.txt (line 4)) (2.14.0)
# Requirement already satisfied: mediapipe==0.10.21 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from -r requirements.txt (line 5)) (0.10.21)
# Requirement already satisfied: protobuf==4.25.3 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from -r requirements.txt (line 6)) (4.25.3)
# Requirement already satisfied: numpy==1.26.4 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from -r requirements.txt (line 9)) (1.26.4)
# Requirement already satisfied: pandas==2.3.2 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from -r requirements.txt (line 10)) (2.3.2)
# Requirement already satisfied: scipy==1.15.3 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from -r requirements.txt (line 11)) (1.15.3)
# Requirement already satisfied: opencv-contrib-python==4.10.0.84 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from -r requirements.txt (line 14)) (4.10.0.84)
# Requirement already satisfied: scikit-learn==1.5.2 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from -r requirements.txt (line 17)) (1.5.2)
# Requirement already satisfied: matplotlib==3.10.6 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from -r requirements.txt (line 20)) (3.10.6)
# Requirement already satisfied: jupyter==1.0.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from -r requirements.txt (line 23)) (1.0.0)
# Requirement already satisfied: ipykernel==6.30.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from -r requirements.txt (line 24)) (6.30.1)
# Requirement already satisfied: ipython==8.37.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from -r requirements.txt (line 25)) (8.37.0)
# Requirement already satisfied: tqdm==4.67.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from -r requirements.txt (line 28)) (4.67.1)
# Requirement already satisfied: pillow==11.3.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from -r requirements.txt (line 29)) (11.3.0)
# Requirement already satisfied: h5py==3.14.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from -r requirements.txt (line 30)) (3.14.0)
# Requirement already satisfied: pytest==8.3.4 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from -r requirements.txt (line 33)) (8.3.4)
# Requirement already satisfied: black==24.10.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from -r requirements.txt (line 34)) (24.10.0)
# Requirement already satisfied: flake8==7.1.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from -r requirements.txt (line 35)) (7.1.1)
# Requirement already satisfied: tensorflow-intel==2.14.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorflow==2.14.0->-r requirements.txt (line 2)) (2.14.0)
# Requirement already satisfied: absl-py>=0.4 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorboard==2.14.0->-r requirements.txt (line 4)) (2.3.1)
# Requirement already satisfied: grpcio>=1.48.2 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorboard==2.14.0->-r requirements.txt (line 4)) (1.74.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorboard==2.14.0->-r requirements.txt (line 4)) (2.40.3)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorboard==2.14.0->-r requirements.txt (line 4)) (1.0.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorboard==2.14.0->-r requirements.txt (line 4)) (3.9)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorboard==2.14.0->-r requirements.txt (line 4)) (2.32.5)
# Requirement already satisfied: setuptools>=41.0.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorboard==2.14.0->-r requirements.txt (line 4)) (65.5.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorboard==2.14.0->-r requirements.txt (line 4)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorboard==2.14.0->-r requirements.txt (line 4)) (3.1.3)
# Requirement already satisfied: wheel>=0.26 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorboard==2.14.0->-r requirements.txt (line 4)) (0.45.1)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from mediapipe==0.10.21->-r requirements.txt (line 5)) (25.3.0)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from mediapipe==0.10.21->-r requirements.txt (line 5)) (25.2.10)
# Requirement already satisfied: jax in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from mediapipe==0.10.21->-r requirements.txt (line 5)) (0.4.34)
# Requirement already satisfied: jaxlib in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from mediapipe==0.10.21->-r requirements.txt (line 5)) (0.4.34)
# Requirement already satisfied: sounddevice>=0.4.4 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from mediapipe==0.10.21->-r requirements.txt (line 5)) (0.5.2)
# Requirement already satisfied: sentencepiece in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from mediapipe==0.10.21->-r requirements.txt (line 5)) (0.2.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from pandas==2.3.2->-r requirements.txt (line 10)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from pandas==2.3.2->-r requirements.txt (line 10)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from pandas==2.3.2->-r requirements.txt (line 10)) (2025.2)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from scikit-learn==1.5.2->-r requirements.txt (line 17)) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from scikit-learn==1.5.2->-r requirements.txt (line 17)) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from matplotlib==3.10.6->-r requirements.txt (line 20)) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from matplotlib==3.10.6->-r requirements.txt (line 20)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from matplotlib==3.10.6->-r requirements.txt (line 20)) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from matplotlib==3.10.6->-r requirements.txt (line 20)) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from matplotlib==3.10.6->-r requirements.txt (line 20)) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from matplotlib==3.10.6->-r requirements.txt (line 20)) (3.2.3)
# Requirement already satisfied: notebook in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyter==1.0.0->-r requirements.txt (line 23)) (7.4.5)
# Requirement already satisfied: qtconsole in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyter==1.0.0->-r requirements.txt (line 23)) (5.7.0)
# Requirement already satisfied: jupyter-console in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyter==1.0.0->-r requirements.txt (line 23)) (6.6.3)
# Requirement already satisfied: nbconvert in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyter==1.0.0->-r requirements.txt (line 23)) (7.16.6)
# Requirement already satisfied: ipywidgets in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyter==1.0.0->-r requirements.txt (line 23)) (8.1.7)
# Requirement already satisfied: comm>=0.1.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from ipykernel==6.30.1->-r requirements.txt (line 24)) (0.2.3)
# Requirement already satisfied: debugpy>=1.6.5 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from ipykernel==6.30.1->-r requirements.txt (line 24)) (1.8.16)
# Requirement already satisfied: jupyter-client>=8.0.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from ipykernel==6.30.1->-r requirements.txt (line 24)) (8.6.3)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from ipykernel==6.30.1->-r requirements.txt (line 24)) (5.8.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from ipykernel==6.30.1->-r requirements.txt (line 24)) (0.1.7)
# Requirement already satisfied: nest-asyncio>=1.4 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from ipykernel==6.30.1->-r requirements.txt (line 24)) (1.6.0)
# Requirement already satisfied: psutil>=5.7 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from ipykernel==6.30.1->-r requirements.txt (line 24)) (7.0.0)
# Requirement already satisfied: pyzmq>=25 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from ipykernel==6.30.1->-r requirements.txt (line 24)) (27.1.0)
# Requirement already satisfied: tornado>=6.2 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from ipykernel==6.30.1->-r requirements.txt (line 24)) (6.5.2)
# Requirement already satisfied: traitlets>=5.4.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from ipykernel==6.30.1->-r requirements.txt (line 24)) (5.14.3)
# Requirement already satisfied: colorama in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from ipython==8.37.0->-r requirements.txt (line 25)) (0.4.6)
# Requirement already satisfied: decorator in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from ipython==8.37.0->-r requirements.txt (line 25)) (5.2.1)
# Requirement already satisfied: exceptiongroup in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from ipython==8.37.0->-r requirements.txt (line 25)) (1.3.0)
# Requirement already satisfied: jedi>=0.16 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from ipython==8.37.0->-r requirements.txt (line 25)) (0.19.2)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from ipython==8.37.0->-r requirements.txt (line 25)) (3.0.52)
# Requirement already satisfied: pygments>=2.4.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from ipython==8.37.0->-r requirements.txt (line 25)) (2.19.2)
# Requirement already satisfied: stack_data in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from ipython==8.37.0->-r requirements.txt (line 25)) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from ipython==8.37.0->-r requirements.txt (line 25)) (4.15.0)
# Requirement already satisfied: iniconfig in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from pytest==8.3.4->-r requirements.txt (line 33)) (2.1.0)
# Requirement already satisfied: pluggy<2,>=1.5 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from pytest==8.3.4->-r requirements.txt (line 33)) (1.6.0)
# Requirement already satisfied: tomli>=1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from pytest==8.3.4->-r requirements.txt (line 33)) (2.2.1)
# Requirement already satisfied: click>=8.0.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from black==24.10.0->-r requirements.txt (line 34)) (8.2.1)
# Requirement already satisfied: mypy-extensions>=0.4.3 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from black==24.10.0->-r requirements.txt (line 34)) (1.1.0)
# Requirement already satisfied: pathspec>=0.9.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from black==24.10.0->-r requirements.txt (line 34)) (0.12.1)
# Requirement already satisfied: platformdirs>=2 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from black==24.10.0->-r requirements.txt (line 34)) (4.4.0)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from flake8==7.1.1->-r requirements.txt (line 35)) (0.7.0)
# Requirement already satisfied: pycodestyle<2.13.0,>=2.12.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from flake8==7.1.1->-r requirements.txt (line 35)) (2.12.1)
# Requirement already satisfied: pyflakes<3.3.0,>=3.2.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from flake8==7.1.1->-r requirements.txt (line 35)) (3.2.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow==2.14.0->-r requirements.txt (line 2)) (1.6.3)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow==2.14.0->-r requirements.txt (line 2)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow==2.14.0->-r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow==2.14.0->-r requirements.txt (line 2)) (18.1.1)
# Requirement already satisfied: ml-dtypes==0.2.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow==2.14.0->-r requirements.txt (line 2)) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow==2.14.0->-r requirements.txt (line 2)) (3.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow==2.14.0->-r requirements.txt (line 2)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow==2.14.0->-r requirements.txt (line 2)) (3.1.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow==2.14.0->-r requirements.txt (line 2)) (1.14.2)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow==2.14.0->-r requirements.txt (line 2)) (0.31.0)
# Requirement already satisfied: tensorflow-estimator<2.15,>=2.14.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from tensorflow-intel==2.14.0->tensorflow==2.14.0->-r requirements.txt (line 2)) (2.14.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard==2.14.0->-r requirements.txt (line 4)) (5.5.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard==2.14.0->-r requirements.txt (line 4)) (0.4.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard==2.14.0->-r requirements.txt (line 4)) (4.9.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard==2.14.0->-r requirements.txt (line 4)) (2.0.0)
# Requirement already satisfied: wcwidth in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython==8.37.0->-r requirements.txt (line 25)) (0.2.13)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard==2.14.0->-r requirements.txt (line 4)) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard==2.14.0->-r requirements.txt (line 4)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard==2.14.0->-r requirements.txt (line 4)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard==2.14.0->-r requirements.txt (line 4)) (2025.8.3)
# Requirement already satisfied: pyasn1>=0.1.3 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from rsa<5,>=3.1.4->google-auth<3,>=1.6.3->tensorboard==2.14.0->-r requirements.txt (line 4)) (0.6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jedi>=0.16->ipython==8.37.0->-r requirements.txt (line 25)) (0.8.5)
# Requirement already satisfied: pywin32>=300 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel==6.30.1->-r requirements.txt (line 24)) (311)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard==2.14.0->-r requirements.txt (line 4)) (3.3.1)
# Requirement already satisfied: CFFI>=1.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from sounddevice>=0.4.4->mediapipe==0.10.21->-r requirements.txt (line 5)) (1.17.1)
# Requirement already satisfied: pycparser in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe==0.10.21->-r requirements.txt (line 5)) (2.22)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard==2.14.0->-r requirements.txt (line 4)) (2.1.5)
# Requirement already satisfied: widgetsnbextension~=4.0.14 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from ipywidgets->jupyter==1.0.0->-r requirements.txt (line 23)) (4.0.14)
# Requirement already satisfied: jupyterlab_widgets~=3.0.15 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from ipywidgets->jupyter==1.0.0->-r requirements.txt (line 23)) (3.0.15)
# Requirement already satisfied: beautifulsoup4 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 23)) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.0.0->-r requirements.txt (line 23)) (6.2.0)
# Requirement already satisfied: defusedxml in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 23)) (0.7.1)
# Requirement already satisfied: jinja2>=3.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 23)) (3.1.4)
# Requirement already satisfied: jupyterlab-pygments in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 23)) (0.3.0)
# Requirement already satisfied: mistune<4,>=2.0.3 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 23)) (3.1.4)
# Requirement already satisfied: nbclient>=0.5.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 23)) (0.10.2)
# Requirement already satisfied: nbformat>=5.7 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 23)) (5.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from nbconvert->jupyter==1.0.0->-r requirements.txt (line 23)) (1.5.1)
# Requirement already satisfied: webencodings in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert->jupyter==1.0.0->-r requirements.txt (line 23)) (0.5.1)
# Requirement already satisfied: tinycss2<1.5,>=1.1.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from bleach[css]!=5.0.0->nbconvert->jupyter==1.0.0->-r requirements.txt (line 23)) (1.4.0)
# Requirement already satisfied: fastjsonschema>=2.15 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter==1.0.0->-r requirements.txt (line 23)) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from nbformat>=5.7->nbconvert->jupyter==1.0.0->-r requirements.txt (line 23)) (4.25.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0->-r requirements.txt (line 23)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0->-r requirements.txt (line 23)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jsonschema>=2.6->nbformat>=5.7->nbconvert->jupyter==1.0.0->-r requirements.txt (line 23)) (0.27.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from beautifulsoup4->nbconvert->jupyter==1.0.0->-r requirements.txt (line 23)) (2.8)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (2.17.0)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (2.27.3)
# Requirement already satisfied: jupyterlab<4.5,>=4.4.5 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (4.4.7)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (0.2.4)
# Requirement already satisfied: anyio>=3.1.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (4.10.0)
# Requirement already satisfied: argon2-cffi>=21.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (25.1.0)
# Requirement already satisfied: jupyter-events>=0.11.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (0.12.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (0.5.3)
# Requirement already satisfied: overrides>=5.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (7.7.0)
# Requirement already satisfied: prometheus-client>=0.9 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (0.22.1)
# Requirement already satisfied: pywinpty>=2.0.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (3.0.0)
# Requirement already satisfied: send2trash>=1.8.2 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (0.18.1)
# Requirement already satisfied: websocket-client>=1.7 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (1.8.0)
# Requirement already satisfied: async-lru>=1.0.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (2.0.5)
# Requirement already satisfied: httpx<1,>=0.25.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (0.28.1)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyterlab<4.5,>=4.4.5->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (2.3.0)
# Requirement already satisfied: httpcore==1.* in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (1.0.9)
# Requirement already satisfied: h11>=0.16 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from httpcore==1.*->httpx<1,>=0.25.0->jupyterlab<4.5,>=4.4.5->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (0.16.0)
# Requirement already satisfied: babel>=2.10 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (2.17.0)
# Requirement already satisfied: json5>=0.9.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyterlab-server<3,>=2.27.1->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (0.12.1)
# Requirement already satisfied: sniffio>=1.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (1.3.1)
# Requirement already satisfied: argon2-cffi-bindings in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (25.1.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (3.3.0)
# Requirement already satisfied: pyyaml>=5.3 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (6.0.2)
# Requirement already satisfied: rfc3339-validator in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (0.1.1)
# Requirement already satisfied: fqdn in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (1.5.1)
# Requirement already satisfied: isoduration in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (3.0.0)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (1.1.0)
# Requirement already satisfied: uri-template in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (24.11.1)
# Requirement already satisfied: lark>=1.2.2 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (1.2.2)
# Requirement already satisfied: arrow>=0.15.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=2.4.0->notebook->jupyter==1.0.0->-r requirements.txt (line 23)) (2.9.0.20250822)
# Requirement already satisfied: ipython_pygments_lexers in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from qtconsole->jupyter==1.0.0->-r requirements.txt (line 23)) (1.1.1)
# Requirement already satisfied: qtpy>=2.4.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from qtconsole->jupyter==1.0.0->-r requirements.txt (line 23)) (2.4.3)
# Requirement already satisfied: executing>=1.2.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from stack_data->ipython==8.37.0->-r requirements.txt (line 25)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from stack_data->ipython==8.37.0->-r requirements.txt (line 25)) (3.0.0)
# Requirement already satisfied: pure-eval in c:\users\happy\onedrive\바탕 화면\s13p21a602\venv\lib\site-packages (from stack_data->ipython==8.37.0->-r requirements.txt (line 25)) (0.2.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from pathlib import Path
import pickle
import warnings
warnings.filterwarnings('ignore')

from config import ModelConfig as cf

print(f"TensorFlow 버전: {tf.__version__}")
print(f"GPU 사용 가능: {tf.config.list_physical_devices('GPU')}")
# Out:
# TensorFlow 버전: 2.14.0
# GPU 사용 가능: []

# %% [markdown]
# ## 2. 시퀀스 길이 정규화 클래스

# %%
class NormalizeSequenceLength:
    """
    시퀀스 길이를 정규화하는 클래스
    - 패딩: 짧은 시퀀스를 0으로 채움
    - 트리밍: 긴 시퀀스를 균등 샘플링
    """
    
    def pad_or_trim(self, seq: np.ndarray, target_len: int) -> np.ndarray:
        """
        시퀀스를 target_len 길이로 정규화
        
        Args:
            seq: 입력 시퀀스 (2D array)
            target_len: 목표 길이
            
        Returns:
            정규화된 시퀀스
        """
        try:
            # 입력 검증
            if seq is None or seq.size == 0:
                raise ValueError("입력 시퀀스가 비어있습니다.")
            
            if len(seq.shape) != 2:
                raise ValueError(f"시퀀스는 2차원 배열이어야 합니다. 현재 shape: {seq.shape}")
            
            t, F = seq.shape
            
            if target_len <= 0:
                raise ValueError(f"target_len은 양수여야 합니다. 현재 값: {target_len}")
            
            # 길이가 같으면 그대로 반환
            if t == target_len:
                return seq
            
            # 길이가 길면 샘플링
            if t > target_len:
                idx = np.linspace(0, t - 1, target_len).astype(int)
                return seq[idx]
            
            # 길이가 짧으면 패딩
            pad = np.zeros((target_len - t, F), dtype=seq.dtype)
            return np.vstack([seq, pad])
            
        except Exception as e:
            print(f"pad_or_trim 에러: {e}")
            raise

    def nearest_bucket_len(self, t: int, buckets=cf.BUCKETS) -> int:
        """
        현재 길이와 가장 가까운 버킷 길이를 반환
        
        Args:
            t: 현재 시퀀스 길이
            buckets: 사용 가능한 버킷 길이들
            
        Returns:
            가장 가까운 버킷 길이
        """
        try:
            if t <= 0:
                raise ValueError(f"시퀀스 길이는 양수여야 합니다. 현재 값: {t}")
            
            if not buckets or len(buckets) == 0:
                raise ValueError("버킷 리스트가 비어있습니다.")
            
            if any(b <= 0 for b in buckets):
                raise ValueError("모든 버킷 값은 양수여야 합니다.")
            
            return min(buckets, key=lambda b: abs(b - t))
            
        except Exception as e:
            print(f"nearest_bucket_len 에러: {e}")
            raise

# 테스트
normalizer = NormalizeSequenceLength()
test_seq = np.random.rand(15, 225)  # 15프레임 시퀀스
normalized = normalizer.pad_or_trim(test_seq, 60)
print(f"원본: {test_seq.shape} → 정규화: {normalized.shape}")
# Out:
# 원본: (15, 225) → 정규화: (60, 225)

# %% [markdown]
# ## 3. 수어 인식 모델 클래스

# %%
class SignLanguageModel:
    """
    수어 인식을 위한 CNN + LSTM 하이브리드 모델
    
    특징:
    - TimeDistributed CNN으로 프레임별 특징 추출
    - LSTM으로 시계열 패턴 학습
    - 버킷 기반 시퀀스 길이 정규화
    """
    
    def __init__(self):
        """모델 초기화"""
        self.num_classes = cf.NUM_CLASSES
        self.sequence_length = cf.SEQUENCE_LENGTH
        self.feature_dim = cf.FEATURE_DIM
        self.model = None
        self.label_encoder = LabelEncoder()
        self.normalizer = NormalizeSequenceLength()
        
        print(f"모델 설정:")
        print(f"  - 시퀀스 길이: {self.sequence_length}")
        print(f"  - 특성 차원: {self.feature_dim}")
        print(f"  - 클래스 수: {self.num_classes}")
        print(f"  - 버킷: {cf.BUCKETS}")

# %% [markdown]
# ### 3.1 모델 구성

# %%
def build_model(self):
    """
    CNN + LSTM 하이브리드 모델 구성
    
    구조:
    1. TimeDistributed CNN (프레임별 특징 추출)
    2. LSTM (시계열 패턴 학습)
    3. Dense (분류)
    """
    try:
        # 입력 검증
        if self.sequence_length <= 0 or self.feature_dim <= 0:
            raise ValueError(f"잘못된 입력 크기: sequence_length={self.sequence_length}, feature_dim={self.feature_dim}")
        
        print("모델 구성 중...")
        
        # 입력층
        inputs = keras.Input(shape=(self.sequence_length, self.feature_dim))
        
        # CNN을 위한 reshape
        # Conv1D(1차원 합성곱)은 입력을 길이(sequence_length), 채널(feature_dim)으로 받음
        # 아래의 TimeDistributed를 사용하려면 프레임마다 (F,1)로 보이게 해야되므로 reshape 하는 것
        x = layers.Reshape((self.sequence_length, self.feature_dim, 1))(inputs)
        
        # TimeDistributed CNN 블록 1
        # 프레임 별로 Conv1D를 적용, 3은 인접 피처 3개를 한번에 포며 로컬 패턴을 잡는 다는 것
        # BN으로 분포 안정화, MaxPooling으로 피처 길이를 반으로 잘라 요약, Dropout으로 과적합 완화
        x = layers.TimeDistributed(layers.Conv1D(64, 3, activation='relu', padding='same'))(x)
        x = layers.TimeDistributed(layers.BatchNormalization())(x)
        x = layers.TimeDistributed(layers.MaxPooling1D(2))(x)
        x = layers.TimeDistributed(layers.Dropout(cf.DROPOUT_RATE))(x)
        
        # TimeDistributed CNN 블록 2
        # 채널(128)을 늘려 풍부한 패턴으로 표현, Pool로 다시 절반으로 자름
        x = layers.TimeDistributed(layers.Conv1D(128, 3, activation='relu', padding='same'))(x)
        x = layers.TimeDistributed(layers.BatchNormalization())(x)
        x = layers.TimeDistributed(layers.MaxPooling1D(2))(x)
        x = layers.TimeDistributed(layers.Dropout(cf.DROPOUT_RATE))(x)
        
        # TimeDistributed CNN 블록 3
        # 256채널까지로 늘려 표현, GlobalMaxPooling1D를 사용해 프레임 내부 길이축(F/4)를 완전히 접어
        # 프레임을 256차원 벡터로 축약
        # 텐서는 시퀀스 * 프레임 벡터 형태가 되어 LSTM을 위한 입력이 됨.
        x = layers.TimeDistributed(layers.Conv1D(256, 3, activation='relu', padding='same'))(x)
        x = layers.TimeDistributed(layers.BatchNormalization())(x)
        x = layers.TimeDistributed(layers.GlobalMaxPooling1D())(x)
        x = layers.TimeDistributed(layers.Dropout(cf.DROPOUT_RATE))(x)
        
        # LSTM 블록
        # 512와 256은 리턴 시퀀스가 T라는 것은 모든 타임스텝의 출력을 다음 LSTM으로 전달하겠다는 뜻.
        # 그래서 128은 마지막 층이기에 리턴시퀀스가 없음, 대신 요약 벡터만 남겨 문맥 응축
        x = layers.LSTM(512, return_sequences=True, dropout=cf.DROPOUT_RATE)(x)
        x = layers.LSTM(256, return_sequences=True, dropout=cf.DROPOUT_RATE)(x)
        x = layers.LSTM(128, dropout=cf.DROPOUT_RATE)(x)
        
        # 분류기
        # LSTM의 123차원을 비선형 변환으로 확장(512->256), BN/Dropout으로 일반화 성능 확보
        x = layers.Dense(512, activation='relu')(x)
        x = layers.BatchNormalization()(x)
        x = layers.Dropout(0.5)(x)
        
        x = layers.Dense(256, activation='relu')(x)
        x = layers.Dropout(0.5)(x)
        
        # 로짓을 클래스 수 만큼 만들어 softmax 확률을 출력
        outputs = layers.Dense(self.num_classes, activation='softmax')(x)
        
        # 모델 생성
        self.model = keras.Model(inputs, outputs)
        
        # 컴파일
        #clipnorm=1.0 == 그레디언트 폭주 방지(LSTM에서 사용하려면 꼭 해줘야 한다고 함)
        # accuracy = 정답 정확도
        # top_5_accuracy = 정답이 상위 5개 예측(확률) 안에 들어갔는지
        self.model.compile(
            optimizer=keras.optimizers.Adam(learning_rate=cf.LEARNING_RATE, clipnorm=1.0),
            loss='categorical_crossentropy',
            metrics=['accuracy', 'top_5_accuracy']
        )
        
        print("모델 구성 완료!")
        return self.model
        
    except Exception as e:
        print(f"build_model 에러: {e}")
        raise

# SignLanguageModel 클래스에 메서드 추가
SignLanguageModel.build_model = build_model

# %% [markdown]
# ### 3.2 시퀀스 길이 정규화

# %%
def normalize_sequence_length(self, sequence: np.ndarray) -> np.ndarray:
    """
    시퀀스 길이를 고정 길이로 정규화
    
    Args:
        sequence: 입력 시퀀스 (2D array)
        
    Returns:
        정규화된 시퀀스 (SEQUENCE_LENGTH 길이)
    """
    try:
        # 입력 검증
        if sequence is None or sequence.size == 0:
            raise ValueError("입력 시퀀스가 비어있습니다.")
        
        if len(sequence.shape) != 2:
            raise ValueError(f"시퀀스는 2차원 배열이어야 합니다. 현재 shape: {sequence.shape}")
        
        # NaN 값 처리
        sequence = np.nan_to_num(sequence, copy=False).astype(np.float32)
        
        # 고정 길이로 정규화
        seq = self.normalizer.pad_or_trim(sequence, cf.SEQUENCE_LENGTH)
        
        return seq
        
    except Exception as e:
        print(f"normalize_sequence_length 에러: {e}")
        raise

# SignLanguageModel 클래스에 메서드 추가
SignLanguageModel.normalize_sequence_length = normalize_sequence_length

# %% [markdown]
# ### 3.3 데이터 로딩

# %%
def load_processed_data(self, data_path):
    """
    전처리된 landmark 데이터 로드
    
    Args:
        data_path: 데이터 경로
        
    Returns:
        X: 정규화된 시퀀스 데이터
        y: 원-핫 인코딩된 라벨
    """
    try:
        data_path = Path(data_path)
        
        # 경로 검증
        if not data_path.exists():
            raise FileNotFoundError(f"데이터 경로가 존재하지 않습니다: {data_path}")
        
        metadata_path = cf.DATA_ROOT / "dataset_metadata.csv"
        if not metadata_path.exists():
            raise FileNotFoundError(f"메타데이터 파일이 존재하지 않습니다: {metadata_path}")
        
        # 메타데이터 로드
        metadata = pd.read_csv(metadata_path)
        
        if metadata.empty:
            raise ValueError("메타데이터가 비어있습니다.")
        
        # 컬럼 검증
        required_columns = ['landmarks_file', 'word_gloss']
        missing_columns = [col for col in required_columns if col not in metadata.columns]
        if missing_columns:
            raise ValueError(f"메타데이터에 필요한 컬럼이 없습니다: {missing_columns}")
        
        # 데이터 로딩
        X, y = [], []
        failed_files = []
        
        print(f"총 {len(metadata)}개 파일 처리 중...")
        
        for idx, row in metadata.iterrows():
            try:
                landmarks_file = data_path / row['landmarks_file']
                if landmarks_file.exists():
                    landmarks = np.load(landmarks_file)
                    landmarks = self.normalize_sequence_length(landmarks)
                    X.append(landmarks)
                    y.append(row['word_gloss'])
                else:
                    failed_files.append(str(landmarks_file))
                    print(f"경고: 파일이 존재하지 않습니다: {landmarks_file}")
            except Exception as e:
                failed_files.append(str(landmarks_file))
                print(f"경고: 파일 로딩 실패 {landmarks_file}: {e}")
                continue
        
        if len(X) == 0:
            raise ValueError("로드된 데이터가 없습니다. 모든 파일 로딩에 실패했습니다.")
        
        # 데이터 검증
        sample_shape = X[0].shape
        if sample_shape[1] != self.feature_dim:
            raise ValueError(f"특성 차원 불일치: 예상={self.feature_dim}, 실제={sample_shape[1]}")
        
        if len(failed_files) > 0:
            print(f"총 {len(failed_files)}개 파일 로딩에 실패했습니다.")
        
        print(f"성공적으로 로드된 데이터: {len(X)}개")
        print(f"데이터 형태: {np.array(X).shape}")
        
        # 라벨 인코딩
        y_encoded = self.label_encoder.fit_transform(y)
        y_categorical = keras.utils.to_categorical(y_encoded, self.num_classes)
        
        return np.array(X), y_categorical
        
    except Exception as e:
        print(f"load_processed_data 에러: {e}")
        raise

# SignLanguageModel 클래스에 메서드 추가
SignLanguageModel.load_processed_data = load_processed_data

# %% [markdown]
# ### 3.4 모델 학습

# %%
def train(self, data_path, validation_split=0.2):
    """
    모델 학습
    
    Args:
        data_path: 학습 데이터 경로
        validation_split: 검증 데이터 비율
        
    Returns:
        학습 히스토리
    """
    try:
        # 입력 검증
        if not (0 < validation_split < 1):
            raise ValueError(f"validation_split은 0과 1 사이의 값이어야 합니다. 현재 값: {validation_split}")
        
        print("=== 모델 학습 시작 ===")
        
        # 데이터 로딩
        print("데이터 로딩 중...")
        X, y = self.load_processed_data(data_path)
        
        if len(X) < 10:
            raise ValueError(f"학습 데이터가 너무 적습니다. 최소 10개 이상 필요합니다. 현재: {len(X)}개")
        
        # 데이터 분할
        print("데이터 분할 중...")
        try:
            X_train, X_val, y_train, y_val = train_test_split(
                X, y, test_size=validation_split, random_state=42, stratify=y.argmax(axis=1)
            )
        except ValueError as e:
            print(f"stratify 실패, stratify 없이 분할: {e}")
            X_train, X_val, y_train, y_val = train_test_split(
                X, y, test_size=validation_split, random_state=42
            )
        
        print(f"학습 데이터: {len(X_train)}개, 검증 데이터: {len(X_val)}개")
        
        # 모델 구성
        if self.model is None:
            print("모델 구성 중...")
            self.build_model()
        else:
            print("기존 모델 사용")
        
        # 모델 저장 경로 설정
        model_save_path = cf.MODEL_SAVA_PATH
        if not model_save_path.exists():
            model_save_path.mkdir(parents=True, exist_ok=True)
            print(f"모델 저장 경로 생성: {model_save_path}")
        
        # 콜백 설정
        callbacks = [
            keras.callbacks.EarlyStopping(
                monitor='val_accuracy', 
                patience=15, 
                restore_best_weights=True, 
                verbose=1
            ),
            keras.callbacks.ReduceLROnPlateau(
                monitor='val_loss', 
                factor=0.5, 
                patience=7, 
                min_lr=1e-7, 
                verbose=1
            ),
            keras.callbacks.ModelCheckpoint(
                model_save_path / "best_model.h5", 
                monitor='val_accuracy', 
                save_best_only=True, 
                verbose=1
            )
        ]
        
        # Mixed Precision 설정 (GPU 메모리 최적화)
        policy = keras.mixed_precision.Policy('mixed_float16')
        keras.mixed_precision.set_global_policy(policy)
        print("Mixed Precision 활성화")
        
        # 학습 실행
        print("모델 학습 시작...")
        history = self.model.fit(
            X_train, y_train,
            validation_data=(X_val, y_val),
            epochs=cf.EPOCHS,
            batch_size=cf.BATCH_SIZE,
            callbacks=callbacks,
            verbose=1
        )
        
        # 라벨 인코더 저장
        print("라벨 인코더 저장 중...")
        with open(model_save_path / 'label_encoder.pkl', 'wb') as f:
            pickle.dump(self.label_encoder, f)
        
        print("=== 학습 완료 ===")
        return history
        
    except Exception as e:
        print(f"train 에러: {e}")
        raise

# SignLanguageModel 클래스에 메서드 추가
SignLanguageModel.train = train

# %% [markdown]
# ## 학습 관련된 전처리 필요 내용 - 내일 보고 수정 필요

# %%
UPPER_POSE_IDXS = [0, 11, 12, 13, 14, 15, 16]  # 코, 양쪽 어깨(11, 12), 팔꿈치(13, 14), 허리(15, 16)
FACE_IDXS = [1, 2, 3] # 이거 미디어파이프 문서 보고 넣을거 선정해서 넣어야 할 듯.

def _norm_by_shoulders(pts, ref_l, ref_r):
    """
    pts: (N,2) 좌표 집합
    ref_l, ref_r: 좌/우 어깨 좌표 (2,)
    - 원점: 어깨 중점
    - 스케일: 어깨 폭
    """
    center = (ref_l + ref_r) / 2.0 # 양쪽 어깨의 중간 지점
    scale = np.linalg.norm(ref_l - ref_r) + 1e-6 # 
    return (pts - center) / scale

def extract_upperbody_hands_features(rgb_img, hands, pose, face):
    """
    상체(포즈 7점) + 좌/우 손(각 21점) + 얼굴 (25점) 사용해 (F,) 벡터 생성
    F = 7*2 + 21*2 + 21*2 + 25 * 2= 148   """
    H, W, _ = rgb_img.shape
    out = []

    # -------- Pose (상체 점만) --------
    res_pose = pose.process(rgb_img)
    pose_xy = np.zeros((33, 2), dtype=np.float32)
    has_pose = False
    if res_pose.pose_landmarks:
        has_pose = True
        for i, lm in enumerate(res_pose.pose_landmarks.landmark):
            pose_xy[i, 0] = lm.x
            pose_xy[i, 1] = lm.y

    # 어깨 기준 정규화 (어깨가 없으면 전체 0으로 둔다)
    if has_pose:
        left_sh = pose_xy[11]; right_sh = pose_xy[12]
        pose_upper = pose_xy[UPPER_POSE_IDXS]           # (7,2)
        pose_upper = _norm_by_shoulders(pose_upper, left_sh, right_sh)
    else:
        pose_upper = np.zeros((len(UPPER_POSE_IDXS), 2), dtype=np.float32)

    out.append(pose_upper.flatten())  # 7*2 = 14

    # -------- Face (subset) --------
    res_face = face.process(rgb_img)
    if res_face.multi_face_landmarks:
        face_pts = np.array(
            [(lm.x, lm.y) for i, lm in enumerate(res_face.multi_face_landmarks[0].landmark) if i in FACE_IDXS],
            dtype=np.float32
        )

        face_pts = _norm_by_shoulders(face_pts, left_sh, right_sh) if has_pose else face_pts
    else:
        face_pts = np.zeros((len(FACE_IDXS), 2), dtype=np.float32)
    out.append(face_pts.flatten())  # ex) 25 * 2 = 50

    # -------- Hands (좌/우 21점씩) --------
    res_hands = hands.process(rgb_img)

    lh = np.zeros((21, 2), dtype=np.float32)
    rh = np.zeros((21, 2), dtype=np.float32)

    if res_hands.multi_hand_landmarks and res_hands.multi_handedness:
        # 정규화 좌표 기준점: 어깨 (가능하면), 아니면 이미지 중앙
        if has_pose:
            ref_l = pose_xy[11]; ref_r = pose_xy[12]
        else:
            # 포즈가 없으면 화면 가로 1.0 기준으로 임시 스케일/원점 설정
            ref_l = np.array([0.5 - 0.1, 0.5], dtype=np.float32)
            ref_r = np.array([0.5 + 0.1, 0.5], dtype=np.float32)

        for lm, handedness in zip(res_hands.multi_hand_landmarks, res_hands.multi_handedness):
            pts = np.array([(p.x, p.y) for p in lm.landmark], dtype=np.float32)  # (21,2)
            pts = _norm_by_shoulders(pts, ref_l, ref_r)
            label = handedness.classification[0].label  # 'Left' or 'Right'
            if label.lower().startswith('left'):
                lh = pts
            else:
                rh = pts

    out.append(lh.flatten())  # 42
    out.append(rh.flatten())  # 42

    feat = np.concatenate(out, axis=0).astype(np.float32)  # (98,)
    return feat

# %% [markdown]
# # 사용 예시

# %% [markdown]
# # 얘 왜 내려가있음??

# %%
# def build_model(self):
#     """
#     CNN + LSTM 하이브리드 모델 구성
    
#     구조:
#     1. TimeDistributed CNN (프레임별 특징 추출)
#     2. LSTM (시계열 패턴 학습)
#     3. Dense (분류)
#     """
#     try:
#         # 입력 검증
#         if self.sequence_length <= 0 or self.feature_dim <= 0:
#             raise ValueError(f"잘못된 입력 크기: sequence_length={self.sequence_length}, feature_dim={self.feature_dim}")
        
#         print("모델 구성 중...")
        
#         # 입력층
#         inputs = keras.Input(shape=(self.sequence_length, self.feature_dim))
        
#         # CNN을 위한 reshape
#         x = layers.Reshape((self.sequence_length, self.feature_dim, 1))(inputs)
        
#         # TimeDistributed CNN 블록 1
#         x = layers.TimeDistributed(layers.Conv1D(64, 3, activation='relu', padding='same'))(x)
#         x = layers.TimeDistributed(layers.BatchNormalization())(x)
#         x = layers.TimeDistributed(layers.MaxPooling1D(2))(x)
#         x = layers.TimeDistributed(layers.Dropout(cf.DROPOUT_RATE))(x)
        
#         # TimeDistributed CNN 블록 2
#         x = layers.TimeDistributed(layers.Conv1D(128, 3, activation='relu', padding='same'))(x)
#         x = layers.TimeDistributed(layers.BatchNormalization())(x)
#         x = layers.TimeDistributed(layers.MaxPooling1D(2))(x)
#         x = layers.TimeDistributed(layers.Dropout(cf.DROPOUT_RATE))(x)
        
#         # TimeDistributed CNN 블록 3
#         x = layers.TimeDistributed(layers.Conv1D(256, 3, activation='relu', padding='same'))(x)
#         x = layers.TimeDistributed(layers.BatchNormalization())(x)
#         x = layers.TimeDistributed(layers.GlobalMaxPooling1D())(x)
#         x = layers.TimeDistributed(layers.Dropout(cf.DROPOUT_RATE))(x)
        
#         # LSTM 블록
#         x = layers.LSTM(512, return_sequences=True, dropout=cf.DROPOUT_RATE)(x)
#         x = layers.LSTM(256, return_sequences=True, dropout=cf.DROPOUT_RATE)(x)
#         x = layers.LSTM(128, dropout=cf.DROPOUT_RATE)(x)
        
#         # 분류기
#         x = layers.Dense(512, activation='relu')(x)
#         x = layers.BatchNormalization()(x)
#         x = layers.Dropout(0.5)(x)
        
#         x = layers.Dense(256, activation='relu')(x)
#         x = layers.Dropout(0.5)(x)
        
#         outputs = layers.Dense(self.num_classes, activation='softmax')(x)
        
#         # 모델 생성
#         self.model = keras.Model(inputs, outputs)
        
#         # 컴파일
#         self.model.compile(
#             optimizer=keras.optimizers.Adam(learning_rate=cf.LEARNING_RATE, clipnorm=1.0),
#             loss='categorical_crossentropy',
#             metrics=['accuracy', 'top_5_accuracy']
#         )
        
#         print("모델 구성 완료!")
#         return self.model
        
#     except Exception as e:
#         print(f"build_model 에러: {e}")
#         raise

# # SignLanguageModel 클래스에 메서드 추가
# SignLanguageModel.build_model = build_model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 74
#      71         raise
#      73 # SignLanguageModel 클래스에 메서드 추가
# ---> 74 SignLanguageModel.build_model = build_model
#
# NameError: name 'SignLanguageModel' is not defined
